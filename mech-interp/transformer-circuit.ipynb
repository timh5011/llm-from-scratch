# %% [markdown]
# # A Mathematical Framework for Transformer Circuits
# https://transformer-circuits.pub/2021/framework/index.html

# %% [markdown]
# ## Transformer Overview
#
# Mechanistic interpretability requires us to break models down into human-interpretable pieces. It is likely that the most human-interpretable representation and the most computationally efficient representation will be different.
